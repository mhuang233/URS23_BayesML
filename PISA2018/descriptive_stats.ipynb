# %% [markdown]
# ### Descriptive statistics and covariance in the PISA2018 dataset
# Evan Edwards

# %%
# Imports
import pandas as pd
import numpy as np
from statsmodels.stats.descriptivestats import describe

# %%
# Load datasets, and select variables of interest
PISA2018 = pd.read_csv("pisa2018.BayesBook.csv")
variables = ["Female", "ESCS","METASUM","PERFEED","HOMEPOS","ADAPTIVITY","TEACHINT",
             "ICTRES","JOYREAD","ATTLNACT","COMPETE","WORKMAST","GFOFAIL","SWBP",
             "MASTGOAL","BELONG","SCREADCOMP","SCREADDIFF","PISADIFF","PV1READ"]

# %%
# Data processing: converting categorical values to numeric, limiting the scope of the dataset to relevant variables
PISA2018['Female'] = PISA2018['Female'].replace({'Female': 1, 'Male': 0})
PISA2018 = PISA2018[variables]

# %%
# A method to calculate descriptive statistics for a given variable, takes in a series and returns the statistics
def descriptiveStats(data):
    return describe(data, stats = ["mean", "std_err", "std","coef_var", "range", "max",
                                    "min","skew", "kurtosis", "mode", "median"])

# %%
# Printing out the descriptive statistics for each variable in the dataset
for var in variables:
      for keys, value in descriptiveStats(PISA2018[var]).items():
         print(keys +": "+ str(value))
      print()
# Out:
# Female: mean         0.491112
# std_err      0.007188
# std          0.499973
# coef_var     1.018042
# range        1.000000
# max          1.000000
# min          0.000000
# skew         0.035557
# kurtosis     1.001264
# mode         0.000000
# mode_freq    0.508888
# median       0.000000
# Name: Female, dtype: float64
#
# ESCS: mean          0.065083
# std_err       0.014569
# std           1.013390
# coef_var     15.570845
# range         7.349800
# max           3.254500
# min          -4.095300
# skew         -0.400275
# kurtosis      2.931326
# mode         -0.670000
# mode_freq     0.000827
# median        0.154100
# Name: ESCS, dtype: float64
#
# METASUM: mean         -0.083390
# std_err       0.014515
# std           1.009611
# coef_var    -12.107128
# range         3.080000
# max           1.360000
# min          -1.720000
# skew         -0.366113
# kurtosis      1.928865
# mode          0.590000
# mode_freq     0.188094
# median        0.210000
# Name: METASUM, dtype: float64
#
# PERFEED: mean         0.294906
# std_err      0.015046
# std          1.046502
# coef_var     3.548597
# range        3.655600
# max          2.016500
# min         -1.639100
# skew        -0.025115
# kurtosis     2.277468
# mode        -0.325300
# mode_freq    0.183134
# median       0.268200
# Name: PERFEED, dtype: float64
#
# HOMEPOS: mean         -0.031596
# std_err       0.016457
# std           1.144675
# coef_var    -36.229050
# range        13.126500
# max           5.318800
# min          -7.807700
# skew          0.169554
# kurtosis      4.447814
# mode          5.318800
# mode_freq     0.001860
# median       -0.045450
# Name: HOMEPOS, dtype: float64
#
# ADAPTIVITY: mean          0.058095
# std_err       0.013961
# std           0.971044
# coef_var     16.714658
# range         4.272500
# max           2.007300
# min          -2.265200
# skew          0.135221
# kurtosis      3.131213
# mode         -0.578600
# mode_freq     0.154403
# median        0.104100
# Name: ADAPTIVITY, dtype: float64
#
# TEACHINT: mean         0.207876
# std_err      0.013794
# std          0.959440
# coef_var     4.615445
# range        4.042200
# max          1.824500
# min         -2.217700
# skew        -0.044168
# kurtosis     2.655529
# mode         0.174400
# mode_freq    0.245969
# median       0.174400
# Name: TEACHINT, dtype: float64
#
# ICTRES: mean         0.152747
# std_err      0.016161
# std          1.124102
# coef_var     7.359252
# range        7.568900
# max          3.601200
# min         -3.967700
# skew         0.639574
# kurtosis     4.260175
# mode         1.294300
# mode_freq    0.062422
# median       0.089500
# Name: ICTRES, dtype: float64
#
# JOYREAD: mean         -0.089557
# std_err       0.015344
# std           1.067267
# coef_var    -11.917214
# range         5.344700
# max           2.613100
# min          -2.731600
# skew          0.021302
# kurtosis      3.496064
# mode         -0.270400
# mode_freq     0.047747
# median       -0.104200
# Name: JOYREAD, dtype: float64
#
# ATTLNACT: mean         0.283941
# std_err      0.014024
# std          0.975454
# coef_var     3.435413
# range        3.621900
# max          1.084400
# min         -2.537500
# skew        -1.043317
# kurtosis     3.294859
# mode         1.084400
# mode_freq    0.494006
# median       0.466700
# Name: ATTLNACT, dtype: float64
#
# COMPETE: mean         0.250637
# std_err      0.014637
# std          1.018083
# coef_var     4.061989
# range        4.350400
# max          2.005400
# min         -2.345000
# skew        -0.107216
# kurtosis     3.008306
# mode         0.195600
# mode_freq    0.201530
# median       0.195600
# Name: COMPETE, dtype: float64
#
# WORKMAST: mean         0.179676
# std_err      0.014390
# std          1.000898
# coef_var     5.570574
# range        4.552900
# max          1.816400
# min         -2.736500
# skew        -0.119233
# kurtosis     2.835599
# mode        -0.101500
# mode_freq    0.258578
# median      -0.101500
# Name: WORKMAST, dtype: float64
#
# GFOFAIL: mean         0.136643
# std_err      0.015594
# std          1.084663
# coef_var     7.937961
# range        3.784400
# max          1.890500
# min         -1.893900
# skew        -0.039119
# kurtosis     2.316133
# mode         0.463700
# mode_freq    0.154609
# median       0.109700
# Name: GFOFAIL, dtype: float64
#
# SWBP: mean        -0.122728
# std_err      0.014616
# std          1.016626
# coef_var    -8.283605
# range        4.305200
# max          1.238600
# min         -3.066600
# skew        -0.173563
# kurtosis     2.146155
# mode        -0.592800
# mode_freq    0.288136
# median      -0.592800
# Name: SWBP, dtype: float64
#
# MASTGOAL: mean         0.311254
# std_err      0.014630
# std          1.017624
# coef_var     3.269434
# range        4.377600
# max          1.852400
# min         -2.525200
# skew        -0.138717
# kurtosis     2.539169
# mode         1.852400
# mode_freq    0.172179
# median       0.346800
# Name: MASTGOAL, dtype: float64
#
# BELONG: mean        -0.246100
# std_err      0.013970
# std          0.971725
# coef_var    -3.948490
# range        5.992900
# max          2.756200
# min         -3.236700
# skew         1.138318
# kurtosis     5.641561
# mode        -0.318400
# mode_freq    0.133320
# median      -0.318400
# Name: BELONG, dtype: float64
#
# SCREADCOMP: mean         0.266423
# std_err      0.014276
# std          0.992992
# coef_var     3.727122
# range        4.324200
# max          1.883900
# min         -2.440300
# skew         0.091730
# kurtosis     2.576681
# mode         0.122200
# mode_freq    0.314800
# median       0.122200
# Name: SCREADCOMP, dtype: float64
#
# SCREADDIFF: mean          0.088565
# std_err       0.014573
# std           1.013639
# coef_var     11.445098
# range         4.662800
# max           2.775200
# min          -1.887600
# skew         -0.093416
# kurtosis      3.086284
# mode         -0.069700
# mode_freq     0.148615
# median       -0.036200
# Name: SCREADDIFF, dtype: float64
#
# PISADIFF: mean         -0.028055
# std_err       0.014319
# std           0.995968
# coef_var    -35.499975
# range         4.278400
# max           3.006400
# min          -1.272000
# skew          0.350160
# kurtosis      2.691637
# mode          0.270500
# mode_freq     0.346011
# median        0.270500
# Name: PISADIFF, dtype: float64
#
# PV1READ: mean         500.150180
# std_err        1.559251
# std          108.454871
# coef_var       0.216845
# range        707.527000
# max          868.870000
# min          161.343000
# skew          -0.095784
# kurtosis       2.601443
# mode         300.907000
# mode_freq      0.000413
# median       503.637500
# Name: PV1READ, dtype: float64

# %%
# A method that takes 2 parameters for each variable and 1 parameter for setting the return value to be the pearson correlation coefficent if set to true, else returns covariance
def covariance(data1, data2, pearson = False):
    if(pearson):
        return np.corrcoef([data1, data2])[0][1]
    return np.cov([data1, data2])[0][1]

# %%
# A demonstration of the covariance and pearson correlation coefficent between two variables
var1 = "JOYREAD"
var2 = "PV1READ"

print("Covariance between " + var1 + " and " + var2 + ":")
print(str(covariance(PISA2018[var1], PISA2018[var2])) +"\n")

print("Pearson correlation coefficent between " + var1 + " and " + var2 + ":")
print(str(covariance(PISA2018[var1], PISA2018[var2], pearson = True)) +"\n")

# Some additional correlation coefficents between select variables
testVariables = [["Female", "COMPETE"],
                 ["WORKMAST","ESCS"],
                 ["COMPETE", "PISADIFF"]]

for i in range(len(testVariables)):
    print("Pearson correlation coefficent between " + testVariables[i][0] + " and " + testVariables[i][1] + ":")
    print(covariance(PISA2018[testVariables[i][0]], PISA2018[testVariables[i][1]], pearson = True))
# Out:
# Covariance between JOYREAD and PV1READ:
# 35.254649131730474
#
# Pearson correlation coefficent between JOYREAD and PV1READ:
# 0.3045749962237244
#
# Pearson correlation coefficent between Female and COMPETE:
# -0.02036926835911788
# Pearson correlation coefficent between WORKMAST and ESCS:
# 0.11650104458555514
# Pearson correlation coefficent between COMPETE and PISADIFF:
# -0.11547952023660021

# %%
# Finding the largest correlation coefficent between two variables
largest = - np.inf
var1 = ""
var2 = ""

for i in PISA2018:
    for j in PISA2018:
        if(PISA2018[i].name != PISA2018[j].name):
            if largest < covariance(PISA2018[PISA2018[i].name], PISA2018[PISA2018[j].name], pearson = True):
                largest = covariance(PISA2018[PISA2018[i].name], PISA2018[PISA2018[j].name], pearson = True)
                var1 = PISA2018[i].name
                var2 = PISA2018[j].name
                
print(f'Largest correlation is between {var1} and {var2}: {largest}')
# Out:
# Largest correlation is between HOMEPOS and ICTRES: 0.7882022147249816
